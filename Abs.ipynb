# %% [markdown]
# <a href="https://colab.research.google.com/github/OlhaPylyp/Project_Filmoteka/blob/develop/Abs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np

delta = 2
s = pd.Series( np.arange(222, 850+delta, step=delta))
s

df = pd.read_excel('./Metals.xlsx')
df2 = df.transpose()
df2.columns = df2.iloc[0]
df3 = df2[1:]

# plt.figure(figsize=(10, 6))

# for column in ["Sample X1", "Sample X2", "Sample X3"]:
#        plt.plot(df3['Wave'], df3[column], label=column)

# plt.xlabel('Index')
# plt.ylabel('Values')
# plt.title('Графік рядків "Sample X1", "Sample X2", "Sample X3""')
# plt.legend()
# plt.grid(True)

# plt.ylim(0)
# plt.ylim(0, 3)
# plt.xlim(250, 500)
# plt.show

# plt2= plt.figure(figsize=(10, 6))
# for column in ["Sample X16", "Sample X17", "Sample X18"]:
#        plt2.plot(df3['Wave'], df3[column], label=column)

# plt2.xlabel('Index')
# plt2.ylabel('Values')
# plt2.title('Графік рядків "Sample X16", "Sample X17", "Sample X18"')
# plt2.legend()
# plt2.grid(True)

# plt2.ylim(0)
# plt2.ylim(0, 3)
# plt2.xlim(250, 500)
# plt2.show
# Створення двох фігур та їх основних підграфіків
plt1 = plt.figure(figsize=(10, 6))
plt2 = plt.figure(figsize=(10, 6))
plt3= plt.figure(figsize=(10, 6))
plt4= plt.figure(figsize=(10, 6))
plt5_subplot= plt.figure(figsize=(10, 6))
plt6= plt.figure(figsize=(10, 6))
# Побудова графіка для перших чотирьох стовпців
plt1_subplot = plt1.add_subplot(111)
for column in ["Sample X1", "Sample X2", "Sample X3"]:
    plt1_subplot.plot(df3['Wave'], df3[column], label=column)

plt1_subplot.set_xlabel('Wave')
plt1_subplot.set_ylabel('Values')
plt1_subplot.set_title('Графік рядків "Sample X1", "Sample X2", "Sample X3", і "Sample X4"')
plt1_subplot.legend()
plt1_subplot.grid(True)
plt1_subplot.set_ylim(0, 3)
plt1_subplot.set_xlim(250, 500)

# Побудова графіка для стовпців "Sample X16", "Sample X17", "Sample X18"
plt2_subplot = plt2.add_subplot(111)
for column in ["Sample X16", "Sample X17", "Sample X18"]:
    plt2_subplot.plot(df3['Wave'], df3[column], label=column)

plt2_subplot.set_xlabel('Wave')
plt2_subplot.set_ylabel('Values')
plt2_subplot.set_title('Графік рядків "Sample X16", "Sample X17", "Sample X18"')
plt2_subplot.legend()
plt2_subplot.grid(True)
plt2_subplot.set_ylim(0, 3)
plt2_subplot.set_xlim(250, 500)



plt3_subplot = plt3.add_subplot(111)
for column in ["Sample X19", "Sample X20", "Sample X21"]:
    plt3_subplot.plot(df3['Wave'], df3[column], label=column)

plt3_subplot.set_xlabel('Wave')
plt3_subplot.set_ylabel('Values')
plt3_subplot.set_title('Графік рядків "Sample X19", "Sample X20", "Sample X21"')
plt3_subplot.legend()
plt3_subplot.grid(True)
plt3_subplot.set_ylim(0, 3)
plt3_subplot.set_xlim(250, 500)


plt4_subplot = plt4.add_subplot(111)
for column in ["Sample X22", "Sample X23", "Sample X24"]:
    plt3_subplot.plot(df3['Wave'], df3[column], label=column)

plt4_subplot.set_xlabel('Wave')
plt4_subplot.set_ylabel('Values')
plt4_subplot.set_title('Графік рядків "Metal"')
plt4_subplot.legend()
plt4_subplot.grid(True)
plt4_subplot.set_ylim(0, 3)
plt4_subplot.set_xlim(250, 500)

plt5_subplot = plt5.add_subplot(111)
for column in ["Sample X25", "Sample X26", "Sample X27"]:
    plt5_subplot.plot(df3['Wave'], df3[column], label=column)

plt5_subplot.set_xlabel('Wave')
plt5_subplot.set_ylabel('Values')
plt5_subplot.set_title('Графік рядків "Metal"')
plt5_subplot.legend()
plt5_subplot.grid(True)
plt5_subplot.set_ylim(0, 3)
plt5_subplot.set_xlim(250, 500)


plt6_subplot = plt5.add_subplot(111)
for column in ["Sample X28", "Sample X29", "Sample X30"]:
    plt6_subplot.plot(df3['Wave'], df3[column], label=column)

plt6_subplot.set_xlabel('Wave')
plt6_subplot.set_ylabel('Values')
plt6_subplot.set_title('Графік рядків "Metal"')
plt6_subplot.legend()
plt6_subplot.grid(True)
plt6_subplot.set_ylim(0, 3)
plt6_subplot.set_xlim(250, 500)
# Відображення обох графіків
plt.show()

df3
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Content   Wave Sample X1 Sample X2 Sample X3 Sample X16 Sample X17 Sample X18  \
# 220      220.0    2.9755    2.7673    2.7192     2.7378     3.0454     3.2214
# 222      222.0    3.0696    2.7273    2.5853     2.5637     2.5843     2.9079
# 224      224.0       3.5    2.9154    3.1208        3.5     3.0251     3.2795
# 226      226.0      3.27    2.9406    3.1053     3.2422        3.5     3.3488
# 228      228.0    2.9538    3.0837    3.2396     3.0832      2.978     3.1049
# ..         ...       ...       ...       ...        ...        ...        ...
# 842      842.0  -9.11729    0.0975    0.0708     0.1122     0.1079     0.0759
# 844      844.0 -9.159239    0.0974    0.0708     0.1105     0.1058     0.0746
# 846      846.0 -9.201188    0.0986    0.0711     0.1098     0.1081     0.0743
# ...
